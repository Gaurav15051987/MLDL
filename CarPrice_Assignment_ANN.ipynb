# %%
from google.colab import files
data_to_load=files.upload()
# Out:
#      <input type="file" id="files-10efcfba-ff5b-44e8-96bd-24637ba7ebc9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10efcfba-ff5b-44e8-96bd-24637ba7ebc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CarPrice_Assignment.csv to CarPrice_Assignment.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('CarPrice_Assignment.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
plt.scatter(x='price',y='horsepower',data=df)#price show linear hostpower incerase price also increase.

# %%
sns.distplot(df['price'],bins=6)#the outcome is not normally distribute

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.describe().T
# Out:
#                   count          mean  ...       75%       max
# car_ID            205.0    103.000000  ...    154.00    205.00
# symboling         205.0      0.834146  ...      2.00      3.00
# wheelbase         205.0     98.756585  ...    102.40    120.90
# carlength         205.0    174.049268  ...    183.10    208.10
# carwidth          205.0     65.907805  ...     66.90     72.30
# carheight         205.0     53.724878  ...     55.50     59.80
# curbweight        205.0   2555.565854  ...   2935.00   4066.00
# enginesize        205.0    126.907317  ...    141.00    326.00
# boreratio         205.0      3.329756  ...      3.58      3.94
# stroke            205.0      3.255415  ...      3.41      4.17
# compressionratio  205.0     10.142537  ...      9.40     23.00
# horsepower        205.0    104.117073  ...    116.00    288.00
# peakrpm           205.0   5125.121951  ...   5500.00   6600.00
# citympg           205.0     25.219512  ...     30.00     49.00
# ...

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
fig,ax=plt.subplots(1,4,figsize = (25,5))
sns.countplot(x='fueltype',hue='carbody',data=df,ax=ax[0])
sns.countplot(x='aspiration',hue='carbody',data=df,ax=ax[1])
sns.countplot(x='doornumber',hue='carbody',data=df,ax=ax[2])
sns.countplot(x='enginelocation',hue='carbody',data=df,ax=ax[3])
#fig,ax=plt.subplots(1,3,figsize = (25,5))
#sns.countplot(x='BusinessTravel',hue='Attrition',data=df,ax=ax[0])
#sns.countplot(x='EducationField',hue='Attrition',data=df,ax=ax[1])
#sns.countplot(x='JobRole',hue='Attrition',data=df,ax=ax[2])

# %%
labels = ["std","turbo"]
values=df['aspiration'].value_counts().values
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %%
labels = ["two","four"]
values=df['doornumber'].value_counts().values
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %%
labels = ["gas","diseal"]
values=df['fueltype'].value_counts().values
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=labels, autopct='%1.1f%%',shadow=True,startangle=90)
plt.show()

# %%
cat=df.select_dtypes(exclude=['int32','int64','float64'])
num=df.select_dtypes(include=['int32','int64','float64'])

# %%
cat.head()
# Out:
#                     CarName fueltype  ... cylindernumber fuelsystem
# 0        alfa-romero giulia      gas  ...           four       mpfi
# 1       alfa-romero stelvio      gas  ...           four       mpfi
# 2  alfa-romero Quadrifoglio      gas  ...            six       mpfi
# 3               audi 100 ls      gas  ...           four       mpfi
# 4                audi 100ls      gas  ...           five       mpfi
#
# [5 rows x 10 columns]

# %%
cat=cat.drop(['CarName'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cat=cat.apply(LabelEncoder().fit_transform)
cat.head()
# Out:
#    fueltype  aspiration  doornumber  ...  enginetype  cylindernumber  fuelsystem
# 0         1           0           1  ...           0               2           5
# 1         1           0           1  ...           0               2           5
# 2         1           0           1  ...           5               3           5
# 3         1           0           0  ...           3               2           5
# 4         1           0           0  ...           3               1           5
#
# [5 rows x 9 columns]

# %%
df=pd.concat([cat,num],axis=1)

# %%
df.head()
# Out:
#    fueltype  aspiration  doornumber  ...  citympg  highwaympg    price
# 0         1           0           1  ...       21          27  13495.0
# 1         1           0           1  ...       21          27  16500.0
# 2         1           0           1  ...       19          26  16500.0
# 3         1           0           0  ...       24          30  13950.0
# 4         1           0           0  ...       18          22  17450.0
#
# [5 rows x 25 columns]

# %%
##df.to_csv("car111.csv")
#files.download('car111.csv')

# %%
df=df.drop(["symboling"],axis=1)

# %%
df=df.drop(["car_ID"],axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler().fit(df)
z=pd.DataFrame(scaler.transform(df),columns=df.columns)
z.boxplot(vert=False,figsize=(15,10))

# %%
#from sklearn.preprocessing import normalize
#nm = normalize(df)
#cols = df.columns
#df1 = pd.DataFrame(nm, columns = cols)
X = df.drop(["price"], axis = 1)
y = df["price"]

# %%
X=X.drop(['compressionratio','curbweight','carheight','carwidth','cylindernumber','enginetype','carlength','highwaympg','aspiration'],axis=1)

# %%
# Regression Modeling
import statsmodels.api as sm
#performing ols. from the ols result 
#we can see that sex has a p-value of 0.694
#almost 7. And we already know any variable that has 
#a p-value which is greater that 0.5 will not be useful for predicting.
#so we would drop sex
x = sm.add_constant(X)


model = sm.OLS(y, x)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     97.68
# Date:                Wed, 12 Aug 2020   Prob (F-statistic):           6.31e-77
# Time:                        08:26:27   Log-Likelihood:                -1923.9
# No. Observations:                 205   AIC:                             3876.
# Df Residuals:                     191   BIC:                             3922.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -1.908e+04   9612.020     -1.985      0.049    -3.8e+04    -124.651
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn import metrics

# %%
X_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.10,random_state=5)
X_train.head()
# Out:
#      fueltype  doornumber  carbody  ...  horsepower  peakrpm  citympg
# 87          1           0        3  ...         116     5500       23
# 42          1           1        3  ...         100     5500       25
# 117         1           0        3  ...         142     5600       18
# 61          1           1        2  ...          84     4800       26
# 28          1           0        4  ...          88     5000       24
#
# [5 rows x 13 columns]

# %%
X_train.to_csv("car1.csv")
files.download('car1.csv')

# %%
model=LinearRegression()
model.fit(X_train,y_train)
print(x_test.shape)
# Out:
# (21, 13)

# %%
#To retrieve the intercept:
print(model.intercept_)
#For retrieving the slope:
print(model.coef_)
# Out:
# -16768.578092487543
# [-4.28307755e+03 -4.90077566e+02 -9.80913741e+02  6.23970858e+02
#   8.93820841e+03 -1.39809447e+02  3.14927516e+02  1.03952056e+02
#  -2.57405119e+03 -3.22089135e+03  4.16002881e+01  1.95548664e+00
#  -1.35131368e+02]

# %%
y_pred=model.predict(x_test)

# %%
#compare actual output values with predicted values

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df.head(10)
# Out:
#       Actual     Predicted
# 154   7898.0   5293.882288
# 21    5572.0   6380.718438
# 198  18420.0  17866.327083
# 48   35550.0  30769.256444
# 34    7129.0   8559.579831
# 194  12940.0  16376.995466
# 6    17710.0  16988.795952
# 25    6692.0   6700.670473
# 159   7788.0   9834.607026
# 122   7609.0   7532.286924

# %%
# evaluate the performance of the algorithm (MAE - MSE - RMSE)
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn import preprocessing, metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))  
print('MSE:', metrics.mean_squared_error(y_test, y_pred))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('VarScore:',metrics.explained_variance_score(y_test,y_pred))
print("R square error =",r2_score(y_test, y_pred))
# Visualizing Our predictions
fig = plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred)
# Perfect predictions
plt.plot(y_test,y_test,'r')
# Out:
# MAE: 1441.7206332963292
# MSE: 3731545.250939216
# RMSE: 1931.7208004624313
# VarScore: 0.9455828148598595
# R square error = 0.945560857650799

# %%
print(model.predict([[1,0,3,1,0,6,96.3,110,3.17,3.46,116,5500,23]]))
# Out:
# [10721.72543352]

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras import metrics

# %%
model = Sequential()
model.add(Dense(22, input_shape=(13,),kernel_initializer='uniform', activation='relu'))

model.add(Dense(22, kernel_initializer='he_uniform',activation='relu'))

model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_18 (Dense)             (None, 22)                308
# _________________________________________________________________
# dense_19 (Dense)             (None, 22)                506
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 23
# ...
# Total params: 837
# Trainable params: 837
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train,epochs=1000,batch_size=100,  verbose=1, validation_split=0.2)
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 12938142.0000 - val_loss: 12894536.0000
# Epoch 2/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 12935908.0000 - val_loss: 12886890.0000
# Epoch 3/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 12933986.0000 - val_loss: 12883598.0000
# Epoch 4/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 12937625.0000 - val_loss: 12880720.0000
# Epoch 5/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 12946201.0000 - val_loss: 12882872.0000
# Epoch 6/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 12967725.0000 - val_loss: 12887415.0000
# Epoch 7/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 12957708.0000 - val_loss: 12887145.0000
# Epoch 8/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 12952921.0000 - val_loss: 12885654.0000
# Epoch 9/1000
# ...

# %%
y_pred = model.predict(x_test)

from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))  
print('MSE:', metrics.mean_squared_error(y_test, y_pred))  
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('VarScore:',metrics.explained_variance_score(y_test,y_pred))
# Visualizing Our predictions
fig = plt.figure(figsize=(10,5))
plt.scatter(y_test,y_pred)
# Perfect predictions
plt.plot(y_test,y_test,'r')
# Out:
# MAE: 1396.252232142857
# MSE: 3883974.785656157
# RMSE: 1970.7802479363743
# VarScore: 0.9436117697375833

# %%
model.save("Car_Price")
# Out:
# INFO:tensorflow:Assets written to: Car_Price/assets

# %%
from keras.models import load_model 
model = load_model("Car_Price")

# %%
input=[[1,0,3,1,0,6,96.3,110,3.17,3.46,116,5500,23]]

# %%
prediction = model.predict(input)
print(prediction)
# Out:
# WARNING:tensorflow:9 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f39395f2400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[10786.619]]
